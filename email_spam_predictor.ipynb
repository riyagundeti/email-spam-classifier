# %%
import pandas as pd

data = {
    "text": [
        "Win money now",
        "Meeting at 4 PM",
        "Claim your free prize",
        "Project deadline tomorrow",
        "Congratulations you won"
    ],
    "label": ["spam", "notspam", "spam", "notspam", "spam"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                         text    label
# 0              Win money now     spam
# 1            Meeting at 4 PM  notspam
# 2      Claim your free prize     spam
# 3  Project deadline tomorrow  notspam
# 4    Congratulations you won     spam

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Convert words into numbers
vectorizer = CountVectorizer()

X = vectorizer.fit_transform(df["text"])

# Labels
y = df["label"]

# Train model
model = MultinomialNB()
model.fit(X, y)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
test_message = ["win cash"]



test_data = vectorizer.transform(test_message)

prediction = model.predict(test_data)

print("Prediction:", prediction[0])
# Out:
# Prediction: spam
